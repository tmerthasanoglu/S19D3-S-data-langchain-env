# %% [markdown]
# # 🧪 Kurulumunuzu kontrol edelim

# %% [markdown]
# Aşağıdaki hücreleri çalıştırın. Herhangi biri `False` döndürürse veya hata verirse, yardım için bir eğitmene başvurun.

# %%
from dotenv import load_dotenv
dot_env_loaded = load_dotenv()
dot_env_loaded
# Out:
# True

# %%
import os

gemini_api_key = os.environ.get("GEMINI_API_KEY", None)
google_cloud_project = os.environ.get("GOOGLE_CLOUD_PROJECT", None)

if not (gemini_api_key or google_cloud_project):
    print("Neither Gemini API key nor Google Cloud Project ID found in environment variables.")
    print("Please ask a TA for help.")
else:
    print("All good for now. Proceed to the next cell.")
# Out:
# All good for now. Proceed to the next cell.

# %%
from google import genai

client = genai.Client()

client_created = True if client else False
client_created
# Out:
# True

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash-lite",
    contents="Are you an LLM?",
)
chat_works = True if response else False
chat_works
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response = client.models.generate_content(
#       2     model="gemini-2.5-flash-lite",
#       3     contents="Are you an LLM?",
#       4 )
#       5 chat_works = True if response else False
#       6 chat_works
#
# File ~/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages/google/genai/models.py:5203, in Models.generate_content(self, model, contents, config)
#    5201 while remaining_remote_calls_afc > 0:
#    5202   i += 1
# -> 5203   response = self._generate_content(
#    5204       model=model, contents=contents, config=parsed_config
#    5205   )
#    5207   function_map = _extra_utils.get_function_map(parsed_config)
#    5208   if not function_map:
#
# File ~/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages/google/genai/models.py:3985, in Models._generate_content(self, model, contents, config)
#    3982 request_dict = _common.convert_to_dict(request_dict)
#    3983 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3985 response = self._api_client.request(
#    3986     'post', path, request_dict, http_options
#    3987 )
#    3989 if config is not None and getattr(
#    3990     config, 'should_return_http_response', None
#    3991 ):
#    3992   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages/google/genai/_api_client.py:1388, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1378 def request(
#    1379     self,
#    1380     http_method: str,
#    (...)
#    1383     http_options: Optional[HttpOptionsOrDict] = None,
#    1384 ) -> SdkHttpResponse:
#    1385   http_request = self._build_request(
#    1386       http_method, path, request_dict, http_options
#    1387   )
# -> 1388   response = self._request(http_request, http_options, stream=False)
#    1389   response_body = (
#    1390       response.response_stream[0] if response.response_stream else ''
#    1391   )
#    1392   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages/google/genai/_api_client.py:1224, in BaseApiClient._request(self, http_request, http_options, stream)
#    1221     retry = tenacity.Retrying(**retry_kwargs)
#    1222     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1224 return self._retry(self._request_once, http_request, stream)
#
# File ~/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     418 retry_exc = self.retry_error_cls(fut)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     185 def reraise(self) -> t.NoReturn:
#     186     if self.last_attempt.failed:
# --> 187         raise self.last_attempt.result()
#     188     raise self
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages/google/genai/_api_client.py:1201, in BaseApiClient._request_once(self, http_request, stream)
#    1193 else:
#    1194   response = self._httpx_client.request(
#    1195       method=http_request.method,
#    1196       url=http_request.url,
#    (...)
#    1199       timeout=http_request.timeout,
#    1200   )
# -> 1201   errors.APIError.raise_for_response(response)
#    1202   return HttpResponse(
#    1203       response.headers, response if stream else [response.text]
#    1204   )
#
# File ~/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages/google/genai/errors.py:121, in APIError.raise_for_response(cls, response)
#     118 else:
#     119   response_json = response.body_segments[0].get('error', {})
# --> 121 cls.raise_error(response.status_code, response_json, response)
#
# File ~/.pyenv/versions/3.12.9/envs/langchain-env/lib/python3.12/site-packages/google/genai/errors.py:146, in APIError.raise_error(cls, status_code, response_json, response)
#     132 """Raises an appropriate APIError subclass based on the status code.
#     133
#     134 Args:
#    (...)
#     143   APIError: For other error status codes.
#     144 """
#     145 if 400 <= status_code < 500:
# --> 146   raise ClientError(status_code, response_json, response)
#     147 elif 500 <= status_code < 600:
#     148   raise ServerError(status_code, response_json, response)
#
# ClientError: 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'This API method requires billing to be enabled. Please enable billing on project #cosmic-backbone-473610-u0 by visiting https://console.developers.google.com/billing/enable?project=cosmic-backbone-473610-u0 then retry. If you enabled billing for this project recently, wait a few minutes for the action to propagate to our systems and retry.', 'status': 'PERMISSION_DENIED', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'BILLING_DISABLED', 'domain': 'googleapis.com', 'metadata': {'consoleUrl': 'https://console.developers.google.com/billing/enable?project=cosmic-backbone-473610-u0', 'service': 'aiplatform.googleapis.com', 'containerInfo': 'cosmic-backbone-473610-u0', 'consumer': 'projects/cosmic-backbone-473610-u0'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'This API method requires billing to be enabled. Please enable billing on project #cosmic-backbone-473610-u0 by visiting https://console.developers.google.com/billing/enable?project=cosmic-backbone-473610-u0 then retry. If you enabled billing for this project recently, wait a few minutes for the action to propagate to our systems and retry.'}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Google developers console billing', 'url': 'https://console.developers.google.com/billing/enable?project=cosmic-backbone-473610-u0'}]}]}}

# %%
all_good = client_created and chat_works

from nbresult import ChallengeResult

result = ChallengeResult("setup", all_good=all_good)
result.write()

# %%
print(result.check())

# %% [markdown]
# 🏁 Her şey yolunda gittiyse ve testi geçtiyseniz, bir sonraki projeye geçebilirsiniz.
#
# Önce test sonuçlarınızı commit etmeyi unutmayın.
